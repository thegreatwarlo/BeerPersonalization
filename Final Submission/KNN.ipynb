# %%
# based on Google Colab 
# python 3
# !pip install scikit-surprise
# Out:
# Requirement already satisfied: scikit-surprise in /usr/local/lib/python3.6/dist-packages (1.0.6)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-surprise) (0.13.0)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.6/dist-packages (from scikit-surprise) (1.1.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from scikit-surprise) (1.11.0)
# Requirement already satisfied: numpy>=1.11.2 in /usr/local/lib/python3.6/dist-packages (from scikit-surprise) (1.14.6)

# %%
import pandas as pd
import numpy as np
import os
import itertools as it
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from matplotlib.ticker import FormatStrFormatter
from surprise.model_selection import train_test_split
from surprise import NMF, Reader, Dataset, SVD, NMF, accuracy, KNNWithMeans

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# #### 1. Load Data

# %%
# load metadata from Google Drive 
# save as a list
data = []
one_complete_review = []

with open('/content/gdrive/My Drive/beeradvocate.txt', 'r') as f:
  for i in f: 
    #row = i.decode(encoding = 'UTF-8',errors = 'ignore')
    row = i.replace('beer/', 'beer_').replace('review/','review_') 
    if row == '\n':
      data.append(one_complete_review)
      one_complete_review = []
      continue
    row = row.split(": ", 1)[1].rstrip()
    one_complete_review.append(row)

# %%
# convert list to dataframe
column_names = ['beer_name', 'beer_beerId', 'beer_brewer', 'beer_ABV', 'beer_style', 
                'review_appearance', 'review_aroma', 'review_palate', 'review_taste', 
                'review_overall', 'review_time', 'review_profileName', 'review_text']

df = pd.DataFrame.from_records(data, columns=column_names)

# %% [markdown]
# #### 2. Subset three columns

# %%
# subset data for collabrotive filtering
df1 = df[['beer_name', 'beer_beerId', 'review_profileName', 'review_overall', 'review_time']]
print('Original data size: %s' % str(df1.shape)) 

# remove NA 
df1 = df1[pd.notnull(df1.beer_name) & pd.notnull(df1.review_profileName) & pd.notnull(df1.review_overall)]
# remove blanks
df1 = df1.loc[df1.review_profileName != '']
df1 = df1.loc[df1.beer_name != '']
df1 = df1.loc[df1.review_overall != '']
print('After removing NAs and blanks: %s' % str(df1.shape)) 

# drop duplicate (beer&user) pairs, keep the latest rating
df1['beer_user_pair'] = df1.beer_name + df1.review_profileName
df1 = df1.sort_values(by=['review_time'], ascending=False).drop_duplicates(subset=['beer_user_pair'])
print('After drop duplicate user-item pairs (only keep the latest rating), data size: %s' % str(df1.shape))

# convert review ratings to numberic
df1.review_overall = pd.to_numeric(df1.review_overall)
# Out:
# Original data size: (1586614, 5)
# After removing NAs and blanks: (1586266, 5)
# After drop duplicate user-item pairs (only keep the latest rating), data size: (1561405, 6)

# %%
# subset three columns
cf = df1[['review_profileName', 'beer_name', 'review_overall']]

# sort user by # of reviews
num_review_byuser = df.review_profileName.value_counts()
cnt_user = dict(num_review_byuser)
cf['user_freq'] = [cnt_user.get(x) for x in cf.review_profileName]

# sort beer by # of reviews
num_review_bybeer = df.beer_name.value_counts()
cnt_beer = dict(num_review_bybeer)
cf['beer_freq'] = [cnt_beer.get(x) for x in cf.beer_name]

# drop users with less than 10 reviews
# drop beers with less than 5 reviews
cf = cf.loc[cf.user_freq > 10]
cf = cf.loc[cf.beer_freq > 5]
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()

# %%
print('After removing bottom users and beers,')
print('%d unique beers;' % cf.beer_name.nunique())
print('%d unique users;' % cf.review_profileName.nunique())
print('and %d reviews in total.' % cf.shape[0])
# Out:
# After removing bottom users and beers,
# 18925 unique beers;
# 10189 unique users;
# and 1423856 reviews in total.

# %% [markdown]
# #### 3. Define functions

# %%
# define functions to generate prediction dataframe
# get_Iu and get_Ui are borrowed from Surprise library
def get_Iu(uid):
    """Return the number of items rated by given user
    Args:
        uid: The raw id of the user.
    Returns:
        The number of items rated by the user.
    """
    try:
        return len(trainset.ur[trainset.to_inner_uid(uid)])
    except ValueError:  # user was not part of the trainset
        return 0
    
def get_Ui(iid):
    """Return the number of users that have rated given item
    Args:
        iid: The raw id of the item.
    Returns:
        The number of users that have rated the item.
    """
    try:
        return len(trainset.ir[trainset.to_inner_iid(iid)])
    except ValueError:  # item was not part of the trainset
        return 0

# customized function to get predictions
def get_pred_df(pred):
  pred_df = pd.DataFrame(pred, columns=['uid', 'iid', 'rui', 'est', 'details'])    
  pred_df['Iu'] = pred_df.uid.apply(get_Iu)
  pred_df['Ui'] = pred_df.iid.apply(get_Ui)
  pred_df['err'] = abs(pred_df.est - pred_df.rui)
  
  # append review counts
  pred_df['user_freq'] = [cnt_user.get(x) for x in pred_df.uid]
  pred_df = pred_df.sort_values(by=['uid'])
  
  return pred_df

# %% [markdown]
# #### 4. Train Test Split

# %%
# train test split
reader = Reader(rating_scale=(1, 5))
data = Dataset.load_from_df(cf[['review_profileName', 'beer_name', 'review_overall']], reader)
trainset, testset = train_test_split(data, test_size=.33)

# %% [markdown]
# #### 5. KNN on whole dataset (after dropped bottom users and beers)
# Comments: although this algorithm run through, it takes up ~11GB RAM as noticed by Colab. This shows that KNN methods do not scale well for large dataset.

# %%
# model set up
sim_options = {'name': 'pearson', 'user_based': True, 'min_support':10}  
knnmean = KNNWithMeans(k=300, 
                       min_k=10, 
                       sim_options=sim_options, 
                       verbose=True)
# fit
knnmean.fit(trainset)

# test
knn_pred = knnmean.test(testset)

# predict
knn_pred_df = get_pred_df(knn_pred)
knn_pred_df.head()
# Out:
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
#              uid                     iid  rui       est  \
# 2731    0110x011               Good Mojo  5.0  4.220588
# 238518  0110x011  Schlafly Oatmeal Stout  4.0  4.025864
# 74494   0110x011         10 Commandments  3.5  4.161951
# 447595  0110x011               White Zin  4.5  4.349181
# 52543   0110x011           The Dissident  4.0  4.517313
#
#                                            details   Iu   Ui       err  \
# 2731      {'actual_k': 8, 'was_impossible': False}  102    9  0.779412
# 238518   {'actual_k': 47, 'was_impossible': False}  102  126  0.025864
# 74494   {'actual_k': 120, 'was_impossible': False}  102  194  0.661951
# 447595   {'actual_k': 10, 'was_impossible': False}  102   16  0.150819
# 52543   {'actual_k': 133, 'was_impossible': False}  102  226  0.517313
#
#         user_freq
# 2731          139
# 238518        139
# 74494         139
# 447595        139
# 52543         139

# %%
# predict whole dataset
trainset_s, testset_s = train_test_split(data, test_size=.8)

knn_pred_s = knnmean.test(testset_s)
knn_pred_df_s = get_pred_df(knn_pred_s)
knn_pred_df_s.head()
# Out:
#              uid                                    iid  rui       est  \
# 190004  0110x011             Bourbon County Brand Stout  4.0  4.349813
# 65736   0110x011               Trappist Westvleteren 12  4.5  4.947105
# 8986    0110x011                               Ten FIDY  4.0  4.464221
# 68971   0110x011  AleSmith Speedway Stout - Barrel Aged  3.5  4.514964
# 387797  0110x011          Weihenstephaner Hefeweissbier  5.0  4.969172
#
#                                            details   Iu    Ui       err  \
# 190004  {'actual_k': 300, 'was_impossible': False}  102  1062  0.349813
# 65736   {'actual_k': 300, 'was_impossible': False}  102   763  0.447105
# 8986    {'actual_k': 300, 'was_impossible': False}  102  1087  0.464221
# 68971    {'actual_k': 87, 'was_impossible': False}  102   136  1.014964
# 387797  {'actual_k': 300, 'was_impossible': False}  102  1169  0.030828
#
#         user_freq
# 190004        139
# 65736         139
# 8986          139
# 68971         139
# 387797        139

# %% [markdown]
# #### 6. KNN on two separate sets
#
# Comments: beforing dropping the bottom users and beers, the dataset was too large to run on Colab and led to runtime died everytime, so we need to split the original dataset.  According to exploratory analysis above, 100 reviews is a benchmark that separate users' review_group. Thus, we split the dataset into two parts: users with more than 100 reviews and users less than 100 reviews.
#
# Below, the result shows that this separation lead to a higher accuracy compared to the previous user-based *KNN* that used the whole dataset for training and testing.
#
# Note that parameters used in this section follows from previous gridsearch results. We do not include gridsearch step in this notebook, because it also takes long running time and large memory, thus not necessary/efficient to run each time we compile this notebook.

# %% [markdown]
# ##### Split into two groups
#
# in case kernel shut down on the whole dataset, we will use this two subsets to train KNN
# - users with more than 100 reviews;
# - users with less than 100 reviews.

# %%
# split into two groups
threshold = 100

more = cf.loc[cf.user_freq > threshold]
less = cf.loc[cf.user_freq <= threshold]

more.head()
# Out:
#         review_profileName                 beer_name  review_overall  \
# 1023623               Mark               Fiji Bitter             4.0
# 1077899             bcm119  Wolaver's India Pale Ale             3.5
# 797362               Jason       Lindemans Framboise             3.5
# 808675               Jason  Chapeau Framboise Lambic             4.0
# 961766               Jason              Dooryard Ale             3.0
#
#          user_freq  beer_freq
# 1023623        532          8
# 1077899        175        257
# 797362        2350        903
# 808675        2350         44
# 961766        2350         13

# %%
# set up model
sim_options = {'name': 'pearson', 'user_based': True, 'min_support':10}  
knnmean1 = KNNWithMeans(k=300, 
                       min_k=10, 
                       sim_options=sim_options, 
                       verbose=True)

knnmean2 = KNNWithMeans(k=300, 
                       min_k=10, 
                       sim_options=sim_options, 
                       verbose=True)

# %% [markdown]
# ##### 1) users with more than 100 reviews

# %%
# split train & test 
knn_more = Dataset.load_from_df(more[['review_profileName', 'beer_name', 'review_overall']], reader)
trainset_more, testset_more = train_test_split(knn_more, test_size=.33)

# fit
knnmean1.fit(trainset_more)
# Out:
# Computing the pearson similarity matrix...
# Done computing similarity matrix.

# %%
# test
pred_more = knnmean1.test(testset_more)

# %%
# prediction
pred_more_df = get_pred_df(pred_more)
pred_more_df.head()
# Out:
#              uid                                    iid  rui       est  \
# 65209   0110x011                       Storm King Stout  4.0  4.535019
# 261046  0110x011              Union Jack India Pale Ale  4.5  4.652560
# 16960   0110x011                             Temptation  5.0  4.822557
# 385401  0110x011  Bottleworks 10th Anniversary Wild Ale  5.0  4.619681
# 278817  0110x011                        Two Hearted Ale  4.0  4.825561
#
#                                            details   Iu    Ui       err  \
# 65209   {'actual_k': 300, 'was_impossible': False}  102  1474  0.535019
# 261046  {'actual_k': 215, 'was_impossible': False}  102   439  0.152560
# 16960   {'actual_k': 268, 'was_impossible': False}  102   571  0.177443
# 385401   {'actual_k': 18, 'was_impossible': False}  102    25  0.380319
# 278817  {'actual_k': 300, 'was_impossible': False}  102  1657  0.825561
#
#         user_freq
# 65209         139
# 261046        139
# 16960         139
# 385401        139
# 278817        139

# %% [markdown]
# ##### 2) users with less than 100 reviews

# %%
# split train & test 
knn_less = Dataset.load_from_df(less[['review_profileName', 'beer_name', 'review_overall']], reader)
trainset_less, testset_less = train_test_split(knn_less, test_size=.33)

# fit
knnmean2.fit(trainset_less)
# Out:
# Computing the pearson similarity matrix...
# Done computing similarity matrix.

# %%
# test
pred_less = knnmean2.test(testset_less)

# predict
pred_less_df = get_pred_df(pred_less)
pred_less_df.head()
# Out:
#             uid              iid  rui       est  \
# 30708  01121987  La Fin Du Monde  4.5  4.470588
# 76523  01121987  Boréale Blanche  5.0  4.470588
# 55021  01121987   Faxe Fest Bock  4.0  4.470588
# 12542  01121987        Revenante  4.5  3.864883
# 21361  01121987       Hefeweizen  3.0  4.470588
#
#                                                  details  Iu    Ui       err  \
# 30708           {'actual_k': 0, 'was_impossible': False}  20  1495  0.029412
# 76523           {'actual_k': 0, 'was_impossible': False}  20    12  0.529412
# 55021           {'actual_k': 0, 'was_impossible': False}  20    18  0.470588
# 12542  {'was_impossible': True, 'reason': 'User and/o...  20     6  0.635117
# 21361           {'actual_k': 0, 'was_impossible': False}  20   421  1.470588
#
#        user_freq
# 30708         29
# 76523         29
# 55021         29
# 12542         29
# 21361         29

# %% [markdown]
# #### 7. KNN item-based
# - failed twice: runtime died
# - user-based collabrative filtering takes up 12GB+ RAM, reached the limits of Colab and led to kernel crach every time.

# %% [markdown]
# #### 8. Get Predictions and Errors

# %%
# define function to get group prediction error
def error_bygroup(pred_df, model_name):
  """
  input complete pred_error df
  output pred_error by group
  """
  # cut into groups
  bins = [10, 20, 30, 40, 50, 100, 200, 500, 1000, 2000, 6000]
  labels = ['11-20', '21-30', '31-40', '41-50', '51-100', '101-200', 
            '201-500', '501-1000', '1001-2000', '2001-6000']
  
  # add group label
  pred_df['review_group'] = pd.cut(pred_df['user_freq'], bins = bins, labels = labels)
  
  # calculate group mean
  pred_df = pred_df.groupby('review_group').mean()
  
  # rename the error column
  #pred_df['err'].columns = model_name
  pred_df = pred_df.rename(columns = {'err':model_name})
  return pred_df

# %%
# get prediction error datarfame
knn_err_separate = error_bygroup(knn_pred_df, 'KNN_separate')
knn_err = error_bygroup(knn_pred_df_s, 'KNN')

# %%
# KNN prediction (if it runs through)
knn_pred_df_s
# Out:
#                  uid                                                iid  rui  \
# 190004      0110x011                         Bourbon County Brand Stout  4.0
# 65736       0110x011                           Trappist Westvleteren 12  4.5
# 8986        0110x011                                           Ten FIDY  4.0
# 68971       0110x011              AleSmith Speedway Stout - Barrel Aged  3.5
# 387797      0110x011                      Weihenstephaner Hefeweissbier  5.0
# 591054      0110x011                          Union Jack India Pale Ale  4.5
# 906276      0110x011                           Founders Breakfast Stout  4.5
# 667330      0110x011                                        Phunky Duck  4.5
# 881415      0110x011            The Angel's Share - Bourbon Barrel-Aged  5.0
# 726404      0110x011                Alpha Klaus Christmas (Xmas) Porter  5.0
# 320082      0110x011                                       Cape Cod IPA  3.5
# 611965      0110x011                            Bell's Expedition Stout  4.0
# 640555      0110x011                                           La Folie  5.0
# 1083729     0110x011            AleSmith Decadence 2007 Imperial Porter  3.0
# 742648      0110x011                                     Tröegs Mad Elf  4.5
# 322669      0110x011                         15th Anniversary Wood Aged  3.5
# 727940      0110x011                                     Pure Hoppiness  5.0
# 280108      0110x011                             Sculpin India Pale Ale  4.5
# 1019082     0110x011                                     Biere De Garde  4.0
# 884824      0110x011                                                IPA  4.0
# 646972      0110x011                                       Doggie Claws  3.5
# 347759      0110x011                                     Sanctification  5.0
# 807469      0110x011                                      Blind Pig IPA  4.5
# 66578       0110x011                 Girardin Gueuze 1882 (Black Label)  5.0
# 861706      0110x011                     Firestone 11 - Anniversary Ale  5.0
# 120626      0110x011  Stone Old Guardian Barley Wine Style Ale Aged ...  3.0
# 259144      0110x011                                Lindemans Framboise  4.0
# 467995      0110x011                                   Ne Goeien Saison  4.5
# 1067981     0110x011                   Collaboration Not Litigation Ale  3.0
# 1045903     0110x011                            Rodenbach Classic (Red)  4.0
# ...              ...                                                ...  ...
# 592476   zymurgy4all                               Left Hand Milk Stout  4.0
# 1021269  zymurgy4all                        Rosies Tail Waggin Pale Ale  3.5
# 808290   zymurgy4all          Sierra Nevada Anniversary Ale (2007-2009)  4.0
# 818022   zymurgy4all                                         Milk Stout  3.0
# 6845     zymurgy4all                         Double Dog Double Pale Ale  3.5
# 417110   zymurgy4all                                 Whitbread Pale Ale  4.0
# 1075239  zymurgy4all                                  Leinenkugel's Red  4.0
# 607096   zymurgy4all                                  Full Sail Wassail  4.0
# 268322   zymurgy4all                                Stone Smoked Porter  4.5
# 679929   zymurgy4all                         Tucher Dunkles Hefe Weizen  3.5
# 549090   zymurgy4all                                          The Abyss  4.0
# 36829    zymurgy4all                           Chapeau Framboise Lambic  4.0
# 799934   zymurgy4all                   Crazy Ed's Cave Creek Chili Beer  1.0
# 545946   zymurgy4all                          Leinenkugel's Honey Weiss  4.0
# 302014   zymurgy4all                          Samuel Adams Boston Lager  4.0
# 892317   zymurgy4all                                    Road Dog Porter  4.0
# 559625   zymurgy4all                      Old Chub - Scottish Style Ale  3.5
# 627867   zymurgy4all                          Mackeson Triple XXX Stout  3.5
# 202297   zymurgy4all                        Hennepin (Farmhouse Saison)  4.5
# 328670   zymurgy4all                       Wild Hop Organic Amber Lager  3.0
# 990315   zymurgy4all                                            Bohemia  3.5
# 728746   zymurgy4all                                  Saranac Brown Ale  3.0
# 577956   zymurgy4all                         Sea Dog Blue Paw Wheat Ale  3.0
# 169267   zymurgy4all                          Leinenkugel's Berry Weiss  3.0
# 1037789  zymurgy4all                                         Copperhook  4.5
# 278474   zymurgy4all                           Kingfisher Premium Lager  4.0
# 861889   zymurgy4all                           Samuel Adams Cream Stout  5.0
# 304526   zymurgy4all                                         Tiger Beer  3.0
# 1083823  zymurgy4all                        Yuengling Traditional Lager  5.0
# 569645   zymurgy4all                                        Hocus Pocus  4.5
#
#               est                                     details   Iu    Ui  \
# 190004   4.349813  {'actual_k': 300, 'was_impossible': False}  102  1062
# 65736    4.947105  {'actual_k': 300, 'was_impossible': False}  102   763
# 8986     4.464221  {'actual_k': 300, 'was_impossible': False}  102  1087
# 68971    4.514964   {'actual_k': 87, 'was_impossible': False}  102   136
# 387797   4.969172  {'actual_k': 300, 'was_impossible': False}  102  1169
# 591054   4.599340  {'actual_k': 239, 'was_impossible': False}  102   439
# 906276   4.700928  {'actual_k': 300, 'was_impossible': False}  102  1507
# 667330   4.220588    {'actual_k': 6, 'was_impossible': False}  102    10
# 881415   4.532440  {'actual_k': 186, 'was_impossible': False}  102   325
# 726404   4.638627  {'actual_k': 230, 'was_impossible': False}  102   434
# 320082   4.430352   {'actual_k': 12, 'was_impossible': False}  102    24
# 611965   4.260877  {'actual_k': 300, 'was_impossible': False}  102  1061
# 640555   4.563241  {'actual_k': 255, 'was_impossible': False}  102   461
# 1083729  4.378687   {'actual_k': 53, 'was_impossible': False}  102    71
# 742648   4.228074  {'actual_k': 288, 'was_impossible': False}  102   668
# 322669   4.175455  {'actual_k': 104, 'was_impossible': False}  102   168
# 727940   4.690970  {'actual_k': 200, 'was_impossible': False}  102   329
# 280108   4.802718  {'actual_k': 300, 'was_impossible': False}  102   833
# 1019082  4.267330   {'actual_k': 56, 'was_impossible': False}  102    78
# 884824   4.031862  {'actual_k': 287, 'was_impossible': False}  102   693
# 646972   4.410342  {'actual_k': 179, 'was_impossible': False}  102   299
# 347759   4.693314  {'actual_k': 175, 'was_impossible': False}  102   281
# 807469   4.760802  {'actual_k': 300, 'was_impossible': False}  102   696
# 66578    4.711815  {'actual_k': 196, 'was_impossible': False}  102   314
# 861706   4.752143   {'actual_k': 87, 'was_impossible': False}  102   119
# 120626   3.856095   {'actual_k': 17, 'was_impossible': False}  102    23
# 259144   4.166218  {'actual_k': 211, 'was_impossible': False}  102   575
# 467995   4.539329   {'actual_k': 40, 'was_impossible': False}  102    48
# 1067981  4.085965  {'actual_k': 224, 'was_impossible': False}  102   404
# 1045903  4.458203  {'actual_k': 145, 'was_impossible': False}  102   339
# ...           ...                                         ...  ...   ...
# 592476   3.921005  {'actual_k': 171, 'was_impossible': False}   58   754
# 1021269  3.844828    {'actual_k': 5, 'was_impossible': False}   58     9
# 808290   4.182830  {'actual_k': 188, 'was_impossible': False}   58   620
# 818022   4.013316   {'actual_k': 95, 'was_impossible': False}   58   343
# 6845     3.725976  {'actual_k': 131, 'was_impossible': False}   58   583
# 417110   3.607020   {'actual_k': 81, 'was_impossible': False}   58   168
# 1075239  3.373871   {'actual_k': 90, 'was_impossible': False}   58   226
# 607096   3.938880   {'actual_k': 87, 'was_impossible': False}   58   268
# 268322   4.216492  {'actual_k': 225, 'was_impossible': False}   58   999
# 679929   3.855180   {'actual_k': 50, 'was_impossible': False}   58   107
# 549090   4.515730  {'actual_k': 127, 'was_impossible': False}   58   849
# 36829    3.750650   {'actual_k': 14, 'was_impossible': False}   58    30
# 799934   1.331585   {'actual_k': 82, 'was_impossible': False}   58   158
# 545946   3.197829  {'actual_k': 108, 'was_impossible': False}   58   288
# 302014   4.081110  {'actual_k': 266, 'was_impossible': False}   58  1496
# 892317   3.645414  {'actual_k': 175, 'was_impossible': False}   58   517
# 559625   4.109967  {'actual_k': 185, 'was_impossible': False}   58   791
# 627867   4.155814  {'actual_k': 112, 'was_impossible': False}   58   388
# 202297   4.273766  {'actual_k': 244, 'was_impossible': False}   58  1159
# 328670   3.206561   {'actual_k': 41, 'was_impossible': False}   58    79
# 990315   3.626706  {'actual_k': 103, 'was_impossible': False}   58   262
# 728746   3.540652   {'actual_k': 69, 'was_impossible': False}   58   155
# 577956   3.279062   {'actual_k': 76, 'was_impossible': False}   58   190
# 169267   2.756506   {'actual_k': 86, 'was_impossible': False}   58   225
# 1037789  3.607689   {'actual_k': 54, 'was_impossible': False}   58   144
# 278474   2.748530   {'actual_k': 63, 'was_impossible': False}   58   202
# 861889   4.122295  {'actual_k': 231, 'was_impossible': False}   58   812
# 304526   3.152675   {'actual_k': 78, 'was_impossible': False}   58   206
# 1083823  3.750397  {'actual_k': 178, 'was_impossible': False}   58   833
# 569645   3.623826   {'actual_k': 67, 'was_impossible': False}   58   162
#
#               err  user_freq review_group
# 190004   0.349813        139      101-200
# 65736    0.447105        139      101-200
# 8986     0.464221        139      101-200
# 68971    1.014964        139      101-200
# 387797   0.030828        139      101-200
# 591054   0.099340        139      101-200
# 906276   0.200928        139      101-200
# 667330   0.279412        139      101-200
# 881415   0.467560        139      101-200
# 726404   0.361373        139      101-200
# 320082   0.930352        139      101-200
# 611965   0.260877        139      101-200
# 640555   0.436759        139      101-200
# 1083729  1.378687        139      101-200
# 742648   0.271926        139      101-200
# 322669   0.675455        139      101-200
# 727940   0.309030        139      101-200
# 280108   0.302718        139      101-200
# 1019082  0.267330        139      101-200
# 884824   0.031862        139      101-200
# 646972   0.910342        139      101-200
# 347759   0.306686        139      101-200
# 807469   0.260802        139      101-200
# 66578    0.288185        139      101-200
# 861706   0.247857        139      101-200
# 120626   0.856095        139      101-200
# 259144   0.166218        139      101-200
# 467995   0.039329        139      101-200
# 1067981  1.085965        139      101-200
# 1045903  0.458203        139      101-200
# ...           ...        ...          ...
# 592476   0.078995         94       51-100
# 1021269  0.344828         94       51-100
# 808290   0.182830         94       51-100
# 818022   1.013316         94       51-100
# 6845     0.225976         94       51-100
# 417110   0.392980         94       51-100
# 1075239  0.626129         94       51-100
# 607096   0.061120         94       51-100
# 268322   0.283508         94       51-100
# 679929   0.355180         94       51-100
# 549090   0.515730         94       51-100
# 36829    0.249350         94       51-100
# 799934   0.331585         94       51-100
# 545946   0.802171         94       51-100
# 302014   0.081110         94       51-100
# 892317   0.354586         94       51-100
# 559625   0.609967         94       51-100
# 627867   0.655814         94       51-100
# 202297   0.226234         94       51-100
# 328670   0.206561         94       51-100
# 990315   0.126706         94       51-100
# 728746   0.540652         94       51-100
# 577956   0.279062         94       51-100
# 169267   0.243494         94       51-100
# 1037789  0.892311         94       51-100
# 278474   1.251470         94       51-100
# 861889   0.877705         94       51-100
# 304526   0.152675         94       51-100
# 1083823  1.249603         94       51-100
# 569645   0.876174         94       51-100
#
# [1139085 rows x 10 columns]

# %% [markdown]
# #### Save the model

# %%
import pickle
pickle.dump(knn_pred_df_s,open("/content/gdrive/My Drive/knn_rec.sav", 'wb'))

# %%
# prediction here in this variable
# knn_pred_df_s
